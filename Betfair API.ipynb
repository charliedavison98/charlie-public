# %% [markdown]
# # Exploring Betfair API's

# %% [markdown]
# ### Create session

# %%
import json
import pandas as pd

# %%
import requests
  
application_key = #Application Key
 
payload = #Username and password
headers = {'X-Application': 'test', 'Content-Type': 'application/x-www-form-urlencoded'}
 
resp = requests.post('https://identitysso-cert.betfair.com/api/certlogin', data=payload, cert=('Betfair.crt', 'client-2048.pem'), headers=headers)
 
resp_json = resp.json()
session_token = resp_json['sessionToken']

if resp.status_code == 200:
    print(resp_json['loginStatus'])
    print(session_token)

else:
    print("Request failed.")

# %% [markdown]
# ### Listing events

# %% [markdown]
# eventTypeIds = sport, football = 1

# %%
eventId = "32286072"

# %%
req = [
    {
        "jsonrpc": "2.0",
        "method": "SportsAPING/v1.0/listEvents",
        "params": {
            "filter": {
                "eventTypeIds": ["1"],
                #"marketCountries": ["GB"],
                #"eventIds": [eventId]
                #"inPlayOnly": "False"
            }
        },
        "id": 1
    }
]

# %%
application_key = 'nCIUYW9B6gb101Vi'

headers = {'X-Application': application_key, 
           'X-Authentication': session_token,
           'Accept': 'application/json'
           }


url="https://api.betfair.com/exchange/betting/json-rpc/v1"

jsonrpc_req = json.dumps(req[0])
 
response = requests.post(url, data=jsonrpc_req, headers=headers)
 
print(json.dumps(json.loads(response.text), indent=3))
# Out:
# {
#    "jsonrpc": "2.0",
#    "result": [
#       {
#          "event": {
#             "id": "32338411",
#             "name": "Melgar v Sport Boys (Per)",
#             "countryCode": "PE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T20:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338410",
#             "name": "Carlos Mannucci v Atletico Grau",
#             "countryCode": "PE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T00:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338404",
#             "name": "Sport Huancayo v UTC Cajamarca",
#             "countryCode": "PE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332260",
#             "name": "Kyoto v C-Osaka",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T04:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342497",
#             "name": "Spartans v Albion",
#             "countryCode": "GB",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332257",
#             "name": "Fukuoka v Tosu",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T04:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338403",
#             "name": "Binacional v Asociacion Deportiva Tarma",
#             "countryCode": "PE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T23:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332259",
#             "name": "Albirex Niigata v Yokohama FM",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T04:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340451",
#             "name": "Rot-Weiss Essen v 1860 Munich",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332258",
#             "name": "Kashima v Nagoya",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T04:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32328188",
#             "name": "Vizela v Famalicao",
#             "countryCode": "PT",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32342521",
#             "name": "Nacional Potosi v Real Tomayapo",
#             "countryCode": "BO",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T00:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344568",
#             "name": "Independiente FBC v Sportivo San Lorenzo",
#             "countryCode": "PY",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T00:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334328",
#             "name": "KA Akureyri v Valur",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T16:00:00.000Z"
#          },
#          "marketCount": 23
#       },
#       {
#          "event": {
#             "id": "32328187",
#             "name": "Portimonense v Benfica",
#             "countryCode": "PT",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32328186",
#             "name": "Chaves v Pacos Ferreira",
#             "countryCode": "PT",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32342517",
#             "name": "Hegelmann Litauen v Fk Siauliai",
#             "countryCode": "LT",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342519",
#             "name": "Afturelding v Thor",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T19:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32315895",
#             "name": "Austin FC v FC Dallas",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T00:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32342518",
#             "name": "Grindavik v Grotta",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T19:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32315894",
#             "name": "Houston Dynamo v Seattle Sounders",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T00:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32338419",
#             "name": "Union Comercio v Sporting Cristal",
#             "countryCode": "PE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334323",
#             "name": "Paderborn v FC Heidenheim",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342477",
#             "name": "Leiknir R v Selfoss",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T19:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346573",
#             "name": "CD Quintanar del Rey v CD Illescas",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340431",
#             "name": "San Diego Loyal SC v Rio Grande Valley FC",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T02:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334286",
#             "name": "Slaven Belupo v Lokomotiva",
#             "countryCode": "HR",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T16:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32315854",
#             "name": "Chicago Fire v St Louis City SC",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32332233",
#             "name": "Atl Tucuman v Argentinos Juniors",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T00:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334281",
#             "name": "Mito v Tochigi SC",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T08:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346569",
#             "name": "Santanyi v SE Penya Independent",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334280",
#             "name": "Tokyo-V v FC Machida",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T06:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340424",
#             "name": "Las Vegas Lights FC v Tulsa Roughnecks FC",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T02:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334283",
#             "name": "CD Trofense v Club Football Estrela",
#             "countryCode": "PT",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334276",
#             "name": "NAC Breda v Heracles",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336327",
#             "name": "KaPa v SalPa",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346567",
#             "name": "AA Portuguesa S U20 v EC Sao Bernardo U20",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334279",
#             "name": "Oita v Kumamoto",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T06:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32313793",
#             "name": "Strasbourg v Nice",
#             "countryCode": "FR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:00:00.000Z"
#          },
#          "marketCount": 43
#       },
#       {
#          "event": {
#             "id": "32346561",
#             "name": "Madrid CFF II (W) v FF La Solana (W)",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346560",
#             "name": "CF Union Viera (W) v UD Almeria (W)",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334272",
#             "name": "Stal Mielec v Lechia Gdansk",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T10:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32324032",
#             "name": "Sampdoria v Empoli",
#             "countryCode": "IT",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T18:45:00.000Z"
#          },
#          "marketCount": 7
#       },
#       {
#          "event": {
#             "id": "32334275",
#             "name": "FC Oss v Jong PSV Eindhoven",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340419",
#             "name": "Ceramica Cleopatra v Ghazl El Mahallah",
#             "countryCode": "EG",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T17:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32334274",
#             "name": "Jong Ajax Amsterdam v Jong AZ Alkmaar",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346562",
#             "name": "Atletico Madrid II (W) v CE Europa (W)",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332253",
#             "name": "Shimizu v Fujieda MYFC",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T05:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334301",
#             "name": "Ionikos v Lamia",
#             "countryCode": "GR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332252",
#             "name": "Sendai v Yamagata",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T05:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32330204",
#             "name": "HB Koge v Fredericia",
#             "countryCode": "DK",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T11:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334300",
#             "name": "Panaitolikos v OFI",
#             "countryCode": "GR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340444",
#             "name": "Tampa Bay Rowdies v Detroit City FC",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T23:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334303",
#             "name": "Levadiakos v PAS Giannina",
#             "countryCode": "GR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334302",
#             "name": "Asteras Tripolis v Atromitos",
#             "countryCode": "GR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332249",
#             "name": "Renofa Yamaguchi v Tokushima",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T04:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332248",
#             "name": "Iwata v Thespakusatsu Gunma",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T05:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332251",
#             "name": "Kofu v Jef Utd Chiba",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T05:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32332250",
#             "name": "Kanazawa v Nagasaki",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T05:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346586",
#             "name": "SD Deusto v Leioa",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334293",
#             "name": "Odds BK v Lillestrom",
#             "countryCode": "NO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32315861",
#             "name": "New York Red Bulls v New York City",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T23:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32332247",
#             "name": "Okayama v Omiya",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T04:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334295",
#             "name": "Suwon FC v Jeju Utd",
#             "countryCode": "KR",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T10:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334294",
#             "name": "Stjarnan v IBV",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32315862",
#             "name": "Inter Miami CF v New England",
#             "countryCode": "US",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T23:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32346576",
#             "name": "Torrent CF v Atzeneta UE",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334288",
#             "name": "Ulsan Hyundai Horang-i v FC Seoul",
#             "countryCode": "KR",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T05:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334291",
#             "name": "Hannover v SV Darmstadt",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338386",
#             "name": "Yverdon Sport v Thun",
#             "countryCode": "CH",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T16:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334290",
#             "name": "Jahn Regensburg v Hamburger SV",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342445",
#             "name": "KFC Komarno v FK Raca Bratislava",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342444",
#             "name": "Samorin v FK Puchov",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342447",
#             "name": "Pohronie v MSK Povazska Bystrica",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342446",
#             "name": "FC Kosice v Spartak Myjava",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334248",
#             "name": "Albacete v Alaves",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32338344",
#             "name": "Ind Medellin v Deportivo Pasto",
#             "countryCode": "CO",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32342443",
#             "name": "FK Humenne v Slovan Bratislava II",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342442",
#             "name": "MFK Dolny Kubin v Tatran Presov",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32340394",
#             "name": "Honka Akatemia v HJS Akatemia",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T16:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336293",
#             "name": "FSV Zwickau v Dynamo Dresden",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334245",
#             "name": "Andorra CF v Tenerife",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T14:15:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32336292",
#             "name": "Saarbrucken v Hallescher FC",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336295",
#             "name": "Freiburg II v Elversberg",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334247",
#             "name": "Huesca v Ponferradina",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32336294",
#             "name": "Bayreuth v Viktoria Koln",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334246",
#             "name": "Las Palmas v Villarreal B",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32336288",
#             "name": "Waldhof Mannheim v VFB Oldenburg",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334240",
#             "name": "Randers v Viborg",
#             "countryCode": "DK",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T17:00:00.000Z"
#          },
#          "marketCount": 1
#       },
#       {
#          "event": {
#             "id": "32344509",
#             "name": "Botafogo v Fluminense",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T21:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334268",
#             "name": "Sandnes Ulf v Kristiansund",
#             "countryCode": "NO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344508",
#             "name": "Bragantino SP v Athletico-PR",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T19:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334271",
#             "name": "Rakow Czestochowa v Lech Poznan",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T15:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32334270",
#             "name": "Pogon Szczecin v Miedz Legnica",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T13:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32324030",
#             "name": "Londrina v Ponte Preta",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T18:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334265",
#             "name": "LASK Linz v Red Bull Salzburg",
#             "countryCode": "AT",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T12:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344505",
#             "name": "Flamengo v Corinthians",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-21T19:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32346552",
#             "name": "Wydad Casablanca v Mamelodi Sundowns",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T19:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334264",
#             "name": "Austria Vienna v Rapid Vienna",
#             "countryCode": "AT",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T15:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32344504",
#             "name": "Sao Paulo v Vasco da Gama",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T21:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32344507",
#             "name": "Gremio v Internacional",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-21T21:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334266",
#             "name": "Sturm Graz v Austria Klagenfurt",
#             "countryCode": "AT",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T12:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344506",
#             "name": "Coritiba v Atletico MG",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T21:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334261",
#             "name": "Feyenoord v Go Ahead Eagles",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T14:45:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32334260",
#             "name": "FC Groningen v Ajax",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T12:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344503",
#             "name": "America MG v Fortaleza EC",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T19:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334262",
#             "name": "PSV v Fortuna Sittard",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T18:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32344502",
#             "name": "Cruzeiro MG v Cuiaba",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-22T23:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32342449",
#             "name": "FC Petrzalka v Dubnica",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344497",
#             "name": "Bahia v Goias",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-20T19:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32342448",
#             "name": "MSK Zilina II v Slavoj Trebisov",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346547",
#             "name": "FC Bocholt v Rot-Weiss Oberhausen",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334259",
#             "name": "AZ Alkmaar v Emmen",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T18:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32344499",
#             "name": "Santos v SE Palmeiras",
#             "countryCode": "BR",
#             "timezone": "GMT",
#             "openDate": "2023-05-21T00:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32334258",
#             "name": "Vitesse Arnhem v Cambuur Leeuwarden",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T10:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336268",
#             "name": "Wehen Wiesbaden v Verl",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342415",
#             "name": "VIFK v JBK",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334222",
#             "name": "AIK v IFK Goteborg",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T17:10:00.000Z"
#          },
#          "marketCount": 1
#       },
#       {
#          "event": {
#             "id": "32334212",
#             "name": "Union St Gilloise v Genk",
#             "countryCode": "BE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32334214",
#             "name": "Hradec Kralove v Mlada Boleslav",
#             "countryCode": "CZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T13:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334209",
#             "name": "Slovan Liberec v Ceske Budejovice",
#             "countryCode": "CZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T13:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334211",
#             "name": "Antwerp v Club Brugge",
#             "countryCode": "BE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334236",
#             "name": "Floridsdorfer AC v Grazer AK",
#             "countryCode": "AT",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T08:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346476",
#             "name": "CA Liniers v Villa Mitre",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T19:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "268416",
#             "name": "French Ligue 1",
#             "countryCode": "FR",
#             "timezone": "Europe/London",
#             "openDate": "2018-08-11T14:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32328042",
#             "name": "Nykobing FC v Hillerod Fodbold",
#             "countryCode": "DK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346468",
#             "name": "ASO Chlef v Olympique Akbou",
#             "countryCode": "DZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344419",
#             "name": "PK35 Vantaa (W) v TPS Turku (W)",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T16:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346467",
#             "name": "FC Libertad Gran Mamor\u00e9 v The Strongest",
#             "countryCode": "BO",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32346466",
#             "name": "IF Vestri v IA Akranes",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334204",
#             "name": "Zlate Moravce v Trencin",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T16:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342396",
#             "name": "NJS v FC Kiffen",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336254",
#             "name": "MFK Skalica v Tatran Lip Mikulas",
#             "countryCode": "SK",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32321913",
#             "name": "Sandecja Nowy Sacz v LKS Lodz",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T10:40:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334200",
#             "name": "Waasland-Beveren v Club Brugge B",
#             "countryCode": "BE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32321912",
#             "name": "GKS Tychy v Chrobry Glogow",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T13:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334197",
#             "name": "Estoril Praia v Arouca",
#             "countryCode": "PT",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T19:15:00.000Z"
#          },
#          "marketCount": 1
#       },
#       {
#          "event": {
#             "id": "32334199",
#             "name": "Molenbeek v Anderlecht B",
#             "countryCode": "BE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344397",
#             "name": "Avantul Reghin v CS Universitatea Alba Iulia",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344393",
#             "name": "Viitorul Pandurii II v Hateg",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334152",
#             "name": "Longford v Treaty United",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32313672",
#             "name": "Betis v Rayo Vallecano",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T19:00:00.000Z"
#          },
#          "marketCount": 16
#       },
#       {
#          "event": {
#             "id": "32313669",
#             "name": "Elche v Atletico Madrid",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T14:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32313670",
#             "name": "Espanyol v Barcelona",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334146",
#             "name": "Waterford v Cobh Ramblers",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344413",
#             "name": "AFC Odorheiu Secuiesc v Sepsi OSK II",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334173",
#             "name": "Gefle v Skovde Aik",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T13:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344412",
#             "name": "Jiul Petrosani v Armata Aurul Brad",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334172",
#             "name": "Utsiktens v IK Brage",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346462",
#             "name": "Olimpo v CA Germinal",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344411",
#             "name": "CSM Ramnicu Sarat v Metalul Buzau",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334170",
#             "name": "Taby FK v Sollentuna FF",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342362",
#             "name": "Universitario de Vinto v Atletico Palmaflor Vinto",
#             "countryCode": "BO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T22:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338266",
#             "name": "Union Magdalena v Tolima",
#             "countryCode": "CO",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T21:10:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338263",
#             "name": "Envigado v Rionegro",
#             "countryCode": "CO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T21:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338262",
#             "name": "Boyaca Chico v Millonarios",
#             "countryCode": "CO",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T23:20:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344401",
#             "name": "CS Lotus Baile Felix v Gloria Bistrita",
#             "countryCode": "RO",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334124",
#             "name": "Dundalk v Cork City",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334127",
#             "name": "St Patricks v Drogheda",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32342319",
#             "name": "River Plate (Uru) v Liverpool Montevideo",
#             "countryCode": "UY",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344361",
#             "name": "Deportivo Tachira v Angostura FC",
#             "countryCode": "VE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T22:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344360",
#             "name": "Caracas v Deportivo La Guaira",
#             "countryCode": "VE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T00:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334122",
#             "name": "Bohemians v Derry City",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344355",
#             "name": "Rayo Zuliano v Monagas",
#             "countryCode": "VE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T20:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344354",
#             "name": "Club Tijuana (W) v Guadalajara (W)",
#             "countryCode": "MX",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T03:10:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334141",
#             "name": "Galway Utd v Wexford F.C",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336189",
#             "name": "Coventry v Middlesbrough",
#             "countryCode": "GB",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T11:00:00.000Z"
#          },
#          "marketCount": 44
#       },
#       {
#          "event": {
#             "id": "32313660",
#             "name": "Valladolid v Sevilla",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32336191",
#             "name": "Sunderland v Luton",
#             "countryCode": "GB",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T16:30:00.000Z"
#          },
#          "marketCount": 44
#       },
#       {
#          "event": {
#             "id": "32334137",
#             "name": "Athlone Town v Kerry FC",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338232",
#             "name": "La Equidad v Atletico Bucaramanga",
#             "countryCode": "CO",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T01:15:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334139",
#             "name": "Bray Wanderers v Finn Harps",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32313659",
#             "name": "Celta Vigo v Valencia",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T12:00:00.000Z"
#          },
#          "marketCount": 43
#       },
#       {
#          "event": {
#             "id": "32344378",
#             "name": "HJK Helsinki (W) v HPS (W)",
#             "countryCode": "FI",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T15:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32346421",
#             "name": "SC Schwaz v SC Imst",
#             "countryCode": "AT",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32344373",
#             "name": "Algeciras v Celta Vigo B",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T10:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32334132",
#             "name": "Sligo Rovers v Shelbourne",
#             "countryCode": "IE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T18:45:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32338230",
# ...
#             "name": "Sportive De Tunis v Al Ahly Cairo",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T19:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32345697",
#             "name": "Al Hamriyah v Al Jazira Al Hamra",
#             "countryCode": "AE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:10:00.000Z"
#          },
#          "marketCount": 12
#       },
#       {
#          "event": {
#             "id": "32339555",
#             "name": "Augsburg II v Eichstatt",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339554",
#             "name": "Schweinfurt v DJK Vilzing",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345698",
#             "name": "Masafi v Baynounah",
#             "countryCode": "AE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:10:00.000Z"
#          },
#          "marketCount": 12
#       },
#       {
#          "event": {
#             "id": "32345724",
#             "name": "LKP Motor Lublin v Radunia Stezyca",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32331391",
#             "name": "Greuther Furth v Braunschweig",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T11:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32345727",
#             "name": "Pogon Siedlce v Hutnik Krakow",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345726",
#             "name": "Etoile Carouge v Stade Nyonnais",
#             "countryCode": "CH",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T15:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343672",
#             "name": "Shanghai Shenhua v Wuhan Three Towns",
#             "countryCode": "CN",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T07:30:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32339572",
#             "name": "Istanbulspor v Galatasaray",
#             "countryCode": "TR",
#             "timezone": "GMT",
#             "openDate": "2023-05-16T17:00:00.000Z"
#          },
#          "marketCount": 1
#       },
#       {
#          "event": {
#             "id": "32345718",
#             "name": "MFK Frydek-Mistek v RSM Hodonin",
#             "countryCode": "CZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:30:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339569",
#             "name": "Alvarado v Almagro BA",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32339568",
#             "name": "Almirante Brown v All Boys",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T21:10:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339571",
#             "name": "Patronato v CA Temperley",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T20:55:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339570",
#             "name": "Flandria v Agropecuario",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T18:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32343628",
#             "name": "Liverpool Montevideo v Independiente (Ecu)",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T22:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32343624",
#             "name": "Cerro Porteno v SE Palmeiras",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T22:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32343627",
#             "name": "Ind Medellin v Nacional (Uru)",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T00:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32335429",
#             "name": "ADO Den Haag v FC Dordrecht",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343623",
#             "name": "Bolivar v Barcelona (ECU)",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T00:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32335430",
#             "name": "VVV Venlo v De Graafschap",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343622",
#             "name": "Aucas v Racing Club",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T00:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32343619",
#             "name": "Alianza Lima v Libertad",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T02:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32343644",
#             "name": "Sarajevo v Zeljeznicar",
#             "countryCode": "BA",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345691",
#             "name": "Vidir Gardur v Kormakur/Hvot",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345690",
#             "name": "IH Hafnarfjordur v Kari",
#             "countryCode": "IS",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343633",
#             "name": "Patronato v Olimpia",
#             "timezone": "GMT",
#             "openDate": "2023-05-24T22:00:00.000Z"
#          },
#          "marketCount": 33
#       },
#       {
#          "event": {
#             "id": "32339500",
#             "name": "Alanyaspor v Konyaspor",
#             "countryCode": "TR",
#             "timezone": "GMT",
#             "openDate": "2023-05-16T17:00:00.000Z"
#          },
#          "marketCount": 1
#       },
#       {
#          "event": {
#             "id": "32335406",
#             "name": "Den Bosch v Almere City",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339502",
#             "name": "Carl Zeiss Jena v Babelsberg",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345641",
#             "name": "Cordoba v San Fernando CD",
#             "countryCode": "ES",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32343592",
#             "name": "MS Kfar Kasem v Maccabi Ahi Nazareth",
#             "countryCode": "IL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T13:00:00.000Z"
#          },
#          "marketCount": 19
#       },
#       {
#          "event": {
#             "id": "32339496",
#             "name": "Illertissen v SPVGG Ansbach",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T17:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339488",
#             "name": "Hammarby TFF v Umea FC",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339490",
#             "name": "FC Trollhattan v BK Olympic",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343613",
#             "name": "JS Saoura v Paradou",
#             "countryCode": "DZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T19:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339517",
#             "name": "Preussen Munster v Rot-Weiss Ahlen",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339516",
#             "name": "Fortuna Dusseldorf II v Wattenscheid",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32335416",
#             "name": "PEC Zwolle v Roda JC",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339515",
#             "name": "FC Duren v SC Wiedenbruck",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32341562",
#             "name": "Al-Batin v Al-Feiha",
#             "countryCode": "SA",
#             "timezone": "GMT",
#             "openDate": "2023-05-15T16:00:00.000Z"
#          },
#          "marketCount": 12
#       },
#       {
#          "event": {
#             "id": "32335413",
#             "name": "FC Eindhoven v Helmond Sport",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32335415",
#             "name": "Willem II v Jong FC Utrecht",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339511",
#             "name": "Union La Calera v Coquimbo Unido",
#             "countryCode": "CL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T19:00:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32335414",
#             "name": "MVV Maastricht v SC Telstar",
#             "countryCode": "NL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T18:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339510",
#             "name": "Huachipato v Nublense",
#             "countryCode": "CL",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T16:30:00.000Z"
#          },
#          "marketCount": 2
#       },
#       {
#          "event": {
#             "id": "32339504",
#             "name": "Bahlinger SC v Hessen Kassel",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339460",
#             "name": "VfL Osnabruck v SV Meppen",
#             "countryCode": "DE",
#             "timezone": "GMT",
#             "openDate": "2023-05-14T12:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339457",
#             "name": "Gimnasia Jujuy v Tristan Suarez",
#             "countryCode": "AR",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T00:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345602",
#             "name": "Garbarnia v Polonia Warszawa",
#             "countryCode": "PL",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339485",
#             "name": "IF Sylvia v United IK Nordic",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32339487",
#             "name": "Bodens v Sandvikens",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343579",
#             "name": "Onduparaka FC v Vipers SC",
#             "countryCode": "UG",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T12:59:33.000Z"
#          },
#          "marketCount": 19
#       },
#       {
#          "event": {
#             "id": "32339482",
#             "name": "Ahlafors IF v Torns",
#             "countryCode": "SE",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T14:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32343573",
#             "name": "Hapoel K Saba v Maccabi Petach Tikva",
#             "countryCode": "IL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T13:00:00.000Z"
#          },
#          "marketCount": 15
#       },
#       {
#          "event": {
#             "id": "32343572",
#             "name": "Bnei Yehuda v Ironi Tiberias",
#             "countryCode": "IL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T13:00:08.000Z"
#          },
#          "marketCount": 14
#       },
#       {
#          "event": {
#             "id": "32343574",
#             "name": "Hapoel Nof HaGalil v Hapoel Afula",
#             "countryCode": "IL",
#             "timezone": "GMT",
#             "openDate": "2023-05-12T13:00:49.000Z"
#          },
#          "marketCount": 18
#       },
#       {
#          "event": {
#             "id": "32339478",
#             "name": "Nara Club v FC Osaka",
#             "countryCode": "JP",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T04:00:00.000Z"
#          },
#          "marketCount": 24
#       },
#       {
#          "event": {
#             "id": "32345616",
#             "name": "SK Dynamo Ceske B v TJ Prestice",
#             "countryCode": "CZ",
#             "timezone": "GMT",
#             "openDate": "2023-05-13T08:30:00.000Z"
#          },
#          "marketCount": 24
#       }
#    ],
#    "id": 1
# }

# %% [markdown]
# ### Listing markets

# %%
market_req = [
    {
        "jsonrpc": "2.0",
        "method": "SportsAPING/v1.0/listMarketCatalogue",
        "params": {
            "filter": {
                "eventIds": [eventId],
            },
            "maxResults": "200",
            "marketProjection": [
                "COMPETITION",
                "EVENT",
                "EVENT_TYPE",
                "RUNNER_DESCRIPTION",
                "RUNNER_METADATA",
                "MARKET_START_TIME"
            ]
        },
        "id": 1
    }
]

# %%
application_key = #Application key

headers = {'X-Application': application_key, 
           'X-Authentication': session_token,
           'Accept': 'application/json'
           }


url="https://api.betfair.com/exchange/betting/json-rpc/v1"

jsonrpc_req = json.dumps(market_req[0])
 
market_response = requests.post(url, data=jsonrpc_req, headers=headers)
 
print(json.dumps(json.loads(market_response.text), indent=3))
# Out:
# {
#    "jsonrpc": "2.0",
#    "result": [],
#    "id": 1
# }

# %%
def get_odds(market_id):
    '''Return odds of all runners in a market'''
    
    odds_req = [{
        "jsonrpc": "2.0",
        "method": "SportsAPING/v1.0/listMarketBook",
        "params": {
            "marketIds": [market_id],
            "priceProjection": {
                "priceData": ["EX_BEST_OFFERS", "EX_TRADED"],
                "virtualise": "true"
            }
        },
        "id": 1
    }]
    
    application_key = 'nCIUYW9B6gb101Vi'

    headers = {'X-Application': application_key, 
               'X-Authentication': session_token,
               'Accept': 'application/json'
               }


    url="https://api.betfair.com/exchange/betting/json-rpc/v1"

    jsonrpc_req = json.dumps(odds_req[0])

    odds_response = requests.post(url, data=jsonrpc_req, headers=headers)
    
    odds_json = json.loads(odds_response.text)
    
    return odds_json['result'][0]

# %% [markdown]
# ### Get market price

# %%
odds_req = [{
    "jsonrpc": "2.0",
    "method": "SportsAPING/v1.0/listMarketBook",
    "params": {
        "marketIds": ["1.213708836"],
        "priceProjection": {
            "priceData": ["EX_BEST_OFFERS", "EX_TRADED"],
            "virtualise": "true"
        }
    },
    "id": 1
}]

# %% [markdown]
# Info needed for odds:
# - marketIds
# - selectionIds

# %%
application_key = 'nCIUYW9B6gb101Vi'

headers = {'X-Application': application_key, 
           'X-Authentication': session_token,
           'Accept': 'application/json'
           }


url="https://api.betfair.com/exchange/betting/json-rpc/v1"

jsonrpc_req = json.dumps(odds_req[0])
 
odds_response = requests.post(url, data=jsonrpc_req, headers=headers)
 
print(json.dumps(json.loads(odds_response.text), indent=3))
# Out:
# {
#    "jsonrpc": "2.0",
#    "result": [
#       {
#          "marketId": "1.213708836",
#          "isMarketDataDelayed": false,
#          "status": "CLOSED",
#          "betDelay": 5,
#          "bspReconciled": false,
#          "complete": true,
#          "inplay": false,
#          "numberOfWinners": 1,
#          "numberOfRunners": 2,
#          "numberOfActiveRunners": 0,
#          "totalMatched": 0.0,
#          "totalAvailable": 0.0,
#          "crossMatching": false,
#          "runnersVoidable": false,
#          "version": 5220955521,
#          "runners": [
#             {
#                "selectionId": 47972,
#                "handicap": 0.0,
#                "status": "LOSER",
#                "ex": {
#                   "availableToBack": [],
#                   "availableToLay": [],
#                   "tradedVolume": []
#                }
#             },
#             {
#                "selectionId": 47973,
#                "handicap": 0.0,
#                "status": "WINNER",
#                "ex": {
#                   "availableToBack": [],
#                   "availableToLay": [],
#                   "tradedVolume": []
#                }
#             }
#          ]
#       }
#    ],
#    "id": 1
# }

# %%
def get_largest_market(all_odds):
    '''Return price of largest market size'''
    
    sizes = []
    if len(all_odds) == 0:
        price = 'null'
    else:     
        for i in range(0, len(all_odds)):
            sizes.append(all_odds[i]['size'])
        max_idx = sizes.index(max(sizes))
        price = all_odds[max_idx]['price']

    return price

# %%
def get_risk(price):
    '''Return the risk level'''
    
    if price == 'null':
        risk = 'NA'
    else:
        if price > 1 and price < 1.3:
            risk = 'Low'
        elif price >= 1.3 and price < 1.6:
            risk = 'Medium'
        elif price >= 1.6 and price < 1.9:
            risk = 'High'
        else:
            risk = 'Too high'
        
    return risk

# %%
num_markets = len(json.loads(market_response.text)['result'])
runners = []

for i in range(0, num_markets):
    market_id = json.loads(market_response.text)['result'][i]['marketId']
    market_name = json.loads(market_response.text)['result'][i]['marketName']
    
    num_runners = len(json.loads(market_response.text)['result'][i]['runners']) 
    market_odds = get_odds(market_id)
   
    for j in range(0, num_runners):
        runnerName = json.loads(market_response.text)['result'][i]['runners'][j]['runnerName']
        runnerId = json.loads(market_response.text)['result'][i]['runners'][j]['selectionId']
        selectionId = market_odds['runners'][j]['selectionId']
        handicap = market_odds['runners'][j]['handicap']
        
        if selectionId == runnerId:
            all_odds = market_odds['runners'][j]['ex']['availableToBack']
            price = get_largest_market(all_odds)
            risk = get_risk(price)
        else:
            raise Exception('RunnerId and SelectionId mismatch')
                
        runner = {'marketId': market_id, 'marketName': market_name, 'runnerName': runnerName, 'handicap': handicap, 'runnerId': runnerId, 'runnerOdds': price, 'risk': risk}
        runners.append(runner)

# %%
runners_df = pd.DataFrame(runners)
runners_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Low risk markets

# %%
low_risk_df = runners_df[runners_df['risk'] == 'Low']
print(len(low_risk_df))
low_risk_df.head(20)
# Out:
# 100
#         marketId              marketName        runnerName  handicap  \
# 3    1.213152820    Over/Under 4.5 Goals   Under 4.5 Goals       0.0
# 5    1.213152889    Over/Under 5.5 Goals   Under 5.5 Goals       0.0
# 63   1.213152887    Over/Under 6.5 Goals   Under 6.5 Goals       0.0
# 77   1.213152885    Over/Under 0.5 Goals    Over 0.5 Goals       0.0
# 90   1.213152878    First Half Goals 2.5   Under 2.5 Goals       0.0
# 93   1.213152875     Man City Win to Nil                No       0.0
# 94   1.213152876    Over/Under 7.5 Goals   Under 7.5 Goals       0.0
# 96   1.213152873             Man City +3       Man City +3       0.0
# 100  1.213152874  Real Madrid Win to Nil                No       0.0
# 141  1.213152871          Real Madrid +3    Real Madrid +3       0.0
# 144  1.213152872             Man City +2       Man City +2       0.0
# 148  1.213152804    Cards Over/Under 2.5    Over 2.5 Cards       0.0
# 193  1.213152801    Cards Over/Under 3.5    Over 3.5 Cards       0.0
# 242  1.213152798             Match Shots  18 Or More Shots       0.0
# 243  1.213152798             Match Shots  19 Or More Shots       0.0
# 244  1.213152798             Match Shots  20 Or More Shots       0.0
# 245  1.213152798             Match Shots  21 Or More Shots       0.0
# 246  1.213152798             Match Shots  22 Or More Shots       0.0
# 247  1.213152798             Match Shots  23 Or More Shots       0.0
# 248  1.213152798             Match Shots  24 Or More Shots       0.0
#
#      runnerId runnerOdds risk
# 3     1222347       1.19  Low
# 5     1485567       1.06  Low
# 63    2542448       1.01  Low
# 77    5851483       1.05  Low
# 90      47972       1.14  Low
# 93     110503       1.22  Low
# 94    1485572       1.01  Low
# 96    6563232       1.03  Low
# 100    110503       1.14  Low
# 141   6582713       1.08  Low
# 144   6563231       1.12  Low
# 148   8549142       1.06  Low
# 193   8568125       1.21  Low
# 242  27801359       1.01  Low
# 243  27801356       1.04  Low
# 244  27801369       1.06  Low
# 245  27801372        1.1  Low
# 246  27801374       1.15  Low
# 247  27801373       1.21  Low
# 248  27801365       1.29  Low

# %%
#Store current odds to reflect on after the event has happened
runners_df.to_csv('Games/ManCity-vs-RealMadrid-Runners.csv', index = False)
